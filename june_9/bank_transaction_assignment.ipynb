# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("BankRDD").getOrCreate()

transactions = [
"DEPOSIT","WITHDRAW","TRANSFER","DEPOSIT","BALANCE_CHECK","TRANSFER","DEPOSIT","WITHDRAW",
"LOAN_PAYMENT","DEPOSIT","TRANSFER","WITHDRAW","DEPOSIT","BALANCE_CHECK","TRANSFER","DEPOSIT",
"WITHDRAW","LOAN_PAYMENT","TRANSFER","DEPOSIT","WITHDRAW","DEPOSIT","TRANSFER","BALANCE_CHECK",
"WITHDRAW","DEPOSIT","TRANSFER","LOAN_PAYMENT","DEPOSIT","WITHDRAW","TRANSFER","DEPOSIT",
"BALANCE_CHECK","TRANSFER","WITHDRAW","DEPOSIT","TRANSFER","LOAN_PAYMENT","DEPOSIT","WITHDRAW",
"TRANSFER","BALANCE_CHECK","DEPOSIT","TRANSFER","WITHDRAW","LOAN_PAYMENT","DEPOSIT","TRANSFER",
"BALANCE_CHECK","DEPOSIT"
]
rdd = spark.sparkContext.parallelize(transactions)

# %%
# 1
print(rdd.collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT']

# %%
# 2
print(rdd.count())
# Out:
# 50

# %%
# 3
print(rdd.first())
# Out:
# DEPOSIT

# %%
# 4
print(rdd.take(15))
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER']

# %%
# 5
print(rdd.distinct().collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
# 6
print(rdd.distinct().count())
# Out:
# 5

# %%
# 7
print(rdd.distinct().sortBy(lambda x: x).collect())
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
# 8
print(rdd.map(lambda x: x.lower()).collect())
# Out:
# ['deposit', 'withdraw', 'transfer', 'deposit', 'balance_check', 'transfer', 'deposit', 'withdraw', 'loan_payment', 'deposit', 'transfer', 'withdraw', 'deposit', 'balance_check', 'transfer', 'deposit', 'withdraw', 'loan_payment', 'transfer', 'deposit', 'withdraw', 'deposit', 'transfer', 'balance_check', 'withdraw', 'deposit', 'transfer', 'loan_payment', 'deposit', 'withdraw', 'transfer', 'deposit', 'balance_check', 'transfer', 'withdraw', 'deposit', 'transfer', 'loan_payment', 'deposit', 'withdraw', 'transfer', 'balance_check', 'deposit', 'transfer', 'withdraw', 'loan_payment', 'deposit', 'transfer', 'balance_check', 'deposit']

# %%
# 9
print(rdd.map(lambda x: x.upper()).collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT']

# %%
# 10
print(rdd.map(lambda x: (x, len(x))).collect())
# Out:
# [('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('TRANSFER', 8), ('WITHDRAW', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('DEPOSIT', 7), ('TRANSFER', 8), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('DEPOSIT', 7)]

# %%
# 11
print(rdd.filter(lambda x: x == 'DEPOSIT').collect())
# Out:
# ['DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT', 'DEPOSIT']

# %%
# 12
print(rdd.filter(lambda x: x == 'WITHDRAW').collect())
# Out:
# ['WITHDRAW', 'WITHDRAW', 'WITHDRAW', 'WITHDRAW', 'WITHDRAW', 'WITHDRAW', 'WITHDRAW', 'WITHDRAW', 'WITHDRAW', 'WITHDRAW']

# %%
# 13
print(rdd.filter(lambda x: x == 'TRANSFER').collect())
# Out:
# ['TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER', 'TRANSFER']

# %%
# 14
print(rdd.filter(lambda x: x == 'LOAN_PAYMENT').collect())
# Out:
# ['LOAN_PAYMENT', 'LOAN_PAYMENT', 'LOAN_PAYMENT', 'LOAN_PAYMENT', 'LOAN_PAYMENT']

# %%
# 15
print(rdd.filter(lambda x: 'CHECK' in x).collect())
# Out:
# ['BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK']

# %%
# 16
print(rdd.filter(lambda x: x != 'DEPOSIT').collect())
# Out:
# ['WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'WITHDRAW', 'TRANSFER', 'LOAN_PAYMENT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'TRANSFER', 'LOAN_PAYMENT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'BALANCE_CHECK']

# %%
# 17
print(rdd.filter(lambda x: x != 'TRANSFER').collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'WITHDRAW', 'DEPOSIT', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'WITHDRAW', 'DEPOSIT', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'BALANCE_CHECK', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'BALANCE_CHECK', 'DEPOSIT']

# %%
# 18
print(rdd.filter(lambda x: len(x) > 8).collect())
# Out:
# ['BALANCE_CHECK', 'LOAN_PAYMENT', 'BALANCE_CHECK', 'LOAN_PAYMENT', 'BALANCE_CHECK', 'LOAN_PAYMENT', 'BALANCE_CHECK', 'LOAN_PAYMENT', 'BALANCE_CHECK', 'LOAN_PAYMENT', 'BALANCE_CHECK']

# %%
# 19
print(rdd.filter(lambda x: len(x) < 10).collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'DEPOSIT']

# %%
# 20
print(rdd.filter(lambda x: x.startswith('B')).collect())
# Out:
# ['BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK', 'BALANCE_CHECK']

# %%
# 21
print(rdd.map(lambda x: 'BANK_' + x).collect())
# Out:
# ['BANK_DEPOSIT', 'BANK_WITHDRAW', 'BANK_TRANSFER', 'BANK_DEPOSIT', 'BANK_BALANCE_CHECK', 'BANK_TRANSFER', 'BANK_DEPOSIT', 'BANK_WITHDRAW', 'BANK_LOAN_PAYMENT', 'BANK_DEPOSIT', 'BANK_TRANSFER', 'BANK_WITHDRAW', 'BANK_DEPOSIT', 'BANK_BALANCE_CHECK', 'BANK_TRANSFER', 'BANK_DEPOSIT', 'BANK_WITHDRAW', 'BANK_LOAN_PAYMENT', 'BANK_TRANSFER', 'BANK_DEPOSIT', 'BANK_WITHDRAW', 'BANK_DEPOSIT', 'BANK_TRANSFER', 'BANK_BALANCE_CHECK', 'BANK_WITHDRAW', 'BANK_DEPOSIT', 'BANK_TRANSFER', 'BANK_LOAN_PAYMENT', 'BANK_DEPOSIT', 'BANK_WITHDRAW', 'BANK_TRANSFER', 'BANK_DEPOSIT', 'BANK_BALANCE_CHECK', 'BANK_TRANSFER', 'BANK_WITHDRAW', 'BANK_DEPOSIT', 'BANK_TRANSFER', 'BANK_LOAN_PAYMENT', 'BANK_DEPOSIT', 'BANK_WITHDRAW', 'BANK_TRANSFER', 'BANK_BALANCE_CHECK', 'BANK_DEPOSIT', 'BANK_TRANSFER', 'BANK_WITHDRAW', 'BANK_LOAN_PAYMENT', 'BANK_DEPOSIT', 'BANK_TRANSFER', 'BANK_BALANCE_CHECK', 'BANK_DEPOSIT']

# %%
# 22
print(rdd.map(lambda x: x + '_2025').collect())
# Out:
# ['DEPOSIT_2025', 'WITHDRAW_2025', 'TRANSFER_2025', 'DEPOSIT_2025', 'BALANCE_CHECK_2025', 'TRANSFER_2025', 'DEPOSIT_2025', 'WITHDRAW_2025', 'LOAN_PAYMENT_2025', 'DEPOSIT_2025', 'TRANSFER_2025', 'WITHDRAW_2025', 'DEPOSIT_2025', 'BALANCE_CHECK_2025', 'TRANSFER_2025', 'DEPOSIT_2025', 'WITHDRAW_2025', 'LOAN_PAYMENT_2025', 'TRANSFER_2025', 'DEPOSIT_2025', 'WITHDRAW_2025', 'DEPOSIT_2025', 'TRANSFER_2025', 'BALANCE_CHECK_2025', 'WITHDRAW_2025', 'DEPOSIT_2025', 'TRANSFER_2025', 'LOAN_PAYMENT_2025', 'DEPOSIT_2025', 'WITHDRAW_2025', 'TRANSFER_2025', 'DEPOSIT_2025', 'BALANCE_CHECK_2025', 'TRANSFER_2025', 'WITHDRAW_2025', 'DEPOSIT_2025', 'TRANSFER_2025', 'LOAN_PAYMENT_2025', 'DEPOSIT_2025', 'WITHDRAW_2025', 'TRANSFER_2025', 'BALANCE_CHECK_2025', 'DEPOSIT_2025', 'TRANSFER_2025', 'WITHDRAW_2025', 'LOAN_PAYMENT_2025', 'DEPOSIT_2025', 'TRANSFER_2025', 'BALANCE_CHECK_2025', 'DEPOSIT_2025']

# %%
# 23
print(rdd.map(lambda x: (x, len(x))).collect())
# Out:
# [('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('TRANSFER', 8), ('WITHDRAW', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('TRANSFER', 8), ('DEPOSIT', 7), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('DEPOSIT', 7), ('BALANCE_CHECK', 13), ('TRANSFER', 8), ('WITHDRAW', 8), ('DEPOSIT', 7), ('TRANSFER', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('WITHDRAW', 8), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('DEPOSIT', 7), ('TRANSFER', 8), ('WITHDRAW', 8), ('LOAN_PAYMENT', 12), ('DEPOSIT', 7), ('TRANSFER', 8), ('BALANCE_CHECK', 13), ('DEPOSIT', 7)]

# %%
# 24
print(rdd.map(lambda x: (x, 1)).collect())
# Out:
# [('DEPOSIT', 1), ('WITHDRAW', 1), ('TRANSFER', 1), ('DEPOSIT', 1), ('BALANCE_CHECK', 1), ('TRANSFER', 1), ('DEPOSIT', 1), ('WITHDRAW', 1), ('LOAN_PAYMENT', 1), ('DEPOSIT', 1), ('TRANSFER', 1), ('WITHDRAW', 1), ('DEPOSIT', 1), ('BALANCE_CHECK', 1), ('TRANSFER', 1), ('DEPOSIT', 1), ('WITHDRAW', 1), ('LOAN_PAYMENT', 1), ('TRANSFER', 1), ('DEPOSIT', 1), ('WITHDRAW', 1), ('DEPOSIT', 1), ('TRANSFER', 1), ('BALANCE_CHECK', 1), ('WITHDRAW', 1), ('DEPOSIT', 1), ('TRANSFER', 1), ('LOAN_PAYMENT', 1), ('DEPOSIT', 1), ('WITHDRAW', 1), ('TRANSFER', 1), ('DEPOSIT', 1), ('BALANCE_CHECK', 1), ('TRANSFER', 1), ('WITHDRAW', 1), ('DEPOSIT', 1), ('TRANSFER', 1), ('LOAN_PAYMENT', 1), ('DEPOSIT', 1), ('WITHDRAW', 1), ('TRANSFER', 1), ('BALANCE_CHECK', 1), ('DEPOSIT', 1), ('TRANSFER', 1), ('WITHDRAW', 1), ('LOAN_PAYMENT', 1), ('DEPOSIT', 1), ('TRANSFER', 1), ('BALANCE_CHECK', 1), ('DEPOSIT', 1)]

# %%
# 25
print(rdd.map(lambda x: 'CASH_DEPOSIT' if x == 'DEPOSIT' else x).collect())
# Out:
# ['CASH_DEPOSIT', 'WITHDRAW', 'TRANSFER', 'CASH_DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'CASH_DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'CASH_DEPOSIT', 'TRANSFER', 'WITHDRAW', 'CASH_DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'CASH_DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'CASH_DEPOSIT', 'WITHDRAW', 'CASH_DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'WITHDRAW', 'CASH_DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'CASH_DEPOSIT', 'WITHDRAW', 'TRANSFER', 'CASH_DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'CASH_DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'CASH_DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'CASH_DEPOSIT', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'CASH_DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'CASH_DEPOSIT']

# %%
# 26
print(rdd.map(lambda x: 'CASH_WITHDRAWAL' if x == 'WITHDRAW' else x).collect())
# Out:
# ['DEPOSIT', 'CASH_WITHDRAWAL', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'CASH_WITHDRAWAL', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'CASH_WITHDRAWAL', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'CASH_WITHDRAWAL', 'LOAN_PAYMENT', 'TRANSFER', 'DEPOSIT', 'CASH_WITHDRAWAL', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'CASH_WITHDRAWAL', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'CASH_WITHDRAWAL', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'CASH_WITHDRAWAL', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'CASH_WITHDRAWAL', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT', 'TRANSFER', 'CASH_WITHDRAWAL', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT']

# %%
# 27
print(rdd.map(lambda x: x[::-1]).collect())
# Out:
# ['TISOPED', 'WARDHTIW', 'REFSNART', 'TISOPED', 'KCEHC_ECNALAB', 'REFSNART', 'TISOPED', 'WARDHTIW', 'TNEMYAP_NAOL', 'TISOPED', 'REFSNART', 'WARDHTIW', 'TISOPED', 'KCEHC_ECNALAB', 'REFSNART', 'TISOPED', 'WARDHTIW', 'TNEMYAP_NAOL', 'REFSNART', 'TISOPED', 'WARDHTIW', 'TISOPED', 'REFSNART', 'KCEHC_ECNALAB', 'WARDHTIW', 'TISOPED', 'REFSNART', 'TNEMYAP_NAOL', 'TISOPED', 'WARDHTIW', 'REFSNART', 'TISOPED', 'KCEHC_ECNALAB', 'REFSNART', 'WARDHTIW', 'TISOPED', 'REFSNART', 'TNEMYAP_NAOL', 'TISOPED', 'WARDHTIW', 'REFSNART', 'KCEHC_ECNALAB', 'TISOPED', 'REFSNART', 'WARDHTIW', 'TNEMYAP_NAOL', 'TISOPED', 'REFSNART', 'KCEHC_ECNALAB', 'TISOPED']

# %%
# 28
print(rdd.map(lambda x: x[:3]).collect())
# Out:
# ['DEP', 'WIT', 'TRA', 'DEP', 'BAL', 'TRA', 'DEP', 'WIT', 'LOA', 'DEP', 'TRA', 'WIT', 'DEP', 'BAL', 'TRA', 'DEP', 'WIT', 'LOA', 'TRA', 'DEP', 'WIT', 'DEP', 'TRA', 'BAL', 'WIT', 'DEP', 'TRA', 'LOA', 'DEP', 'WIT', 'TRA', 'DEP', 'BAL', 'TRA', 'WIT', 'DEP', 'TRA', 'LOA', 'DEP', 'WIT', 'TRA', 'BAL', 'DEP', 'TRA', 'WIT', 'LOA', 'DEP', 'TRA', 'BAL', 'DEP']

# %%
# 29
print(rdd.map(lambda x: x[-4:]).collect())
# Out:
# ['OSIT', 'DRAW', 'SFER', 'OSIT', 'HECK', 'SFER', 'OSIT', 'DRAW', 'MENT', 'OSIT', 'SFER', 'DRAW', 'OSIT', 'HECK', 'SFER', 'OSIT', 'DRAW', 'MENT', 'SFER', 'OSIT', 'DRAW', 'OSIT', 'SFER', 'HECK', 'DRAW', 'OSIT', 'SFER', 'MENT', 'OSIT', 'DRAW', 'SFER', 'OSIT', 'HECK', 'SFER', 'DRAW', 'OSIT', 'SFER', 'MENT', 'OSIT', 'DRAW', 'SFER', 'HECK', 'OSIT', 'SFER', 'DRAW', 'MENT', 'OSIT', 'SFER', 'HECK', 'OSIT']

# %%
# 30
codes = {'DEPOSIT': 'D', 'WITHDRAW': 'W', 'TRANSFER': 'T'}
print(rdd.map(lambda x: codes.get(x, x)).collect())
# Out:
# ['D', 'W', 'T', 'D', 'BALANCE_CHECK', 'T', 'D', 'W', 'LOAN_PAYMENT', 'D', 'T', 'W', 'D', 'BALANCE_CHECK', 'T', 'D', 'W', 'LOAN_PAYMENT', 'T', 'D', 'W', 'D', 'T', 'BALANCE_CHECK', 'W', 'D', 'T', 'LOAN_PAYMENT', 'D', 'W', 'T', 'D', 'BALANCE_CHECK', 'T', 'W', 'D', 'T', 'LOAN_PAYMENT', 'D', 'W', 'T', 'BALANCE_CHECK', 'D', 'T', 'W', 'LOAN_PAYMENT', 'D', 'T', 'BALANCE_CHECK', 'D']

# %%
# 31
print(rdd.distinct().collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
# 32
print(rdd.distinct().count())
# Out:
# 5

# %%
# 33
print(rdd.distinct().sortBy(lambda x: x).collect())
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
# 34
print(rdd.distinct().filter(lambda x: 'PAYMENT' in x).collect())
# Out:
# ['LOAN_PAYMENT']

# %%
# 35
print(rdd.distinct().filter(lambda x: 'CHECK' in x).collect())
# Out:
# ['BALANCE_CHECK']

# %%
# 36
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).collect())
# Out:
# [('DEPOSIT', 16), ('WITHDRAW', 10), ('TRANSFER', 13), ('BALANCE_CHECK', 6), ('LOAN_PAYMENT', 5)]

# %%
# 37
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).first())
# Out:
# ('DEPOSIT', 16)

# %%
# 38
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1]).first())
# Out:
# ('LOAN_PAYMENT', 5)

# %%
# 39
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).collect())
# Out:
# [('DEPOSIT', 16), ('WITHDRAW', 10), ('TRANSFER', 13), ('BALANCE_CHECK', 6), ('LOAN_PAYMENT', 5)]

# %%
# 40
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).filter(lambda x: x[1] > 5).collect())
# Out:
# [('DEPOSIT', 16), ('WITHDRAW', 10), ('TRANSFER', 13), ('BALANCE_CHECK', 6)]

# %%
extra_transactions=["DEPOSIT","ATM_WITHDRAWAL","TRANSFER","MOBILE_RECHARGE","BALANCE_CHECK"]
rdd2=spark.sparkContext.parallelize(extra_transactions)

# %%
# 41
print(rdd.union(rdd2).collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'LOAN_PAYMENT', 'TRANSFER', 'DEPOSIT', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'DEPOSIT', 'BALANCE_CHECK', 'TRANSFER', 'WITHDRAW', 'DEPOSIT', 'TRANSFER', 'LOAN_PAYMENT', 'DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT', 'TRANSFER', 'WITHDRAW', 'LOAN_PAYMENT', 'DEPOSIT', 'TRANSFER', 'BALANCE_CHECK', 'DEPOSIT', 'DEPOSIT', 'ATM_WITHDRAWAL', 'TRANSFER', 'MOBILE_RECHARGE', 'BALANCE_CHECK']

# %%
# 42
print(rdd.union(rdd2).count())
# Out:
# 55

# %%
# 43
print(rdd.union(rdd2).distinct().collect())
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT', 'ATM_WITHDRAWAL', 'MOBILE_RECHARGE']

# %%
# 44
print(rdd2.distinct().subtract(rdd.distinct()).collect())
# Out:
# ['ATM_WITHDRAWAL', 'MOBILE_RECHARGE']

# %%
# 45
print(rdd.union(rdd2).map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).collect())
# Out:
# [('DEPOSIT', 17), ('WITHDRAW', 10), ('TRANSFER', 14), ('BALANCE_CHECK', 7), ('LOAN_PAYMENT', 5), ('ATM_WITHDRAWAL', 1), ('MOBILE_RECHARGE', 1)]

# %%
rdd3=spark.sparkContext.parallelize(["DEPOSIT","TRANSFER","BALANCE_CHECK","CREDIT_CARD_PAYMENT","ATM_WITHDRAWAL"])

# %%
# 46
print(rdd.distinct().intersection(rdd3.distinct()).collect())
# Out:
# ['DEPOSIT', 'TRANSFER', 'BALANCE_CHECK']

# %%
# 47
print(rdd.distinct().intersection(rdd3.distinct()).count())
# Out:
# 3

# %%
# 48
print(rdd.distinct().intersection(rdd3.distinct()).sortBy(lambda x: x).collect())
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'TRANSFER']

# %%
# 49
print(rdd.distinct().intersection(rdd3.distinct()).filter(lambda x: 'CHECK' in x).collect())
# Out:
# ['BALANCE_CHECK']

# %%
# 50
print(rdd.distinct().intersection(rdd3.distinct()).filter(lambda x: 'TRANSFER' in x).collect())
# Out:
# ['TRANSFER']

# %%
amounts=[500,1200,3000,4500,800,950,1100,2500,4000,6000,750,1800,2200,3300,4700,
         5200,1500,2600,3700,4800,5900,6200,700,900,1400,1750,2100,2900,3600,4300,
         5100,5800,6500,7200,8100,9200,10500,12000,13500,15000,17000,19000,22000,
         25000,28000,30000,32000,35000,38000,40000]
amount_rdd=spark.sparkContext.parallelize(amounts)

# %%
# 51
print(amount_rdd.sum())
# Out:
# 463750

# %%
# 52
print(amount_rdd.mean())
# Out:
# 9275.0

# %%
# 53
print(amount_rdd.max())
# Out:
# 40000

# %%
# 54
print(amount_rdd.min())
# Out:
# 500

# %%
# 55
print(amount_rdd.filter(lambda x: x > 10000).collect())
# Out:
# [10500, 12000, 13500, 15000, 17000, 19000, 22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]

# %%
# 56
print(amount_rdd.filter(lambda x: x < 2000).collect())
# Out:
# [500, 1200, 800, 950, 1100, 750, 1800, 1500, 700, 900, 1400, 1750]

# %%
# 57
print(amount_rdd.map(lambda x: x + 500).collect())
# Out:
# [1000, 1700, 3500, 5000, 1300, 1450, 1600, 3000, 4500, 6500, 1250, 2300, 2700, 3800, 5200, 5700, 2000, 3100, 4200, 5300, 6400, 6700, 1200, 1400, 1900, 2250, 2600, 3400, 4100, 4800, 5600, 6300, 7000, 7700, 8600, 9700, 11000, 12500, 14000, 15500, 17500, 19500, 22500, 25500, 28500, 30500, 32500, 35500, 38500, 40500]

# %%
# 58
print(amount_rdd.map(lambda x: x * 1.10).collect())
# Out:
# [550.0, 1320.0, 3300.0000000000005, 4950.0, 880.0000000000001, 1045.0, 1210.0, 2750.0, 4400.0, 6600.000000000001, 825.0000000000001, 1980.0000000000002, 2420.0, 3630.0000000000005, 5170.0, 5720.000000000001, 1650.0000000000002, 2860.0000000000005, 4070.0000000000005, 5280.0, 6490.000000000001, 6820.000000000001, 770.0000000000001, 990.0000000000001, 1540.0000000000002, 1925.0000000000002, 2310.0, 3190.0000000000005, 3960.0000000000005, 4730.0, 5610.0, 6380.000000000001, 7150.000000000001, 7920.000000000001, 8910.0, 10120.0, 11550.000000000002, 13200.000000000002, 14850.000000000002, 16500.0, 18700.0, 20900.0, 24200.000000000004, 27500.000000000004, 30800.000000000004, 33000.0, 35200.0, 38500.0, 41800.0, 44000.0]

# %%
# 59
print(amount_rdd.sortBy(lambda x: x).collect())
# Out:
# [500, 700, 750, 800, 900, 950, 1100, 1200, 1400, 1500, 1750, 1800, 2100, 2200, 2500, 2600, 2900, 3000, 3300, 3600, 3700, 4000, 4300, 4500, 4700, 4800, 5100, 5200, 5800, 5900, 6000, 6200, 6500, 7200, 8100, 9200, 10500, 12000, 13500, 15000, 17000, 19000, 22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]

# %%
# 60
print(amount_rdd.sortBy(lambda x: x, ascending=False).collect())
# Out:
# [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000, 15000, 13500, 12000, 10500, 9200, 8100, 7200, 6500, 6200, 6000, 5900, 5800, 5200, 5100, 4800, 4700, 4500, 4300, 4000, 3700, 3600, 3300, 3000, 2900, 2600, 2500, 2200, 2100, 1800, 1750, 1500, 1400, 1200, 1100, 950, 900, 800, 750, 700, 500]

# %%
# 61
print(amount_rdd.sortBy(lambda x: x, ascending=False).take(10))
# Out:
# [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000]

# %%
# 62
print(amount_rdd.sortBy(lambda x: x).take(10))
# Out:
# [500, 700, 750, 800, 900, 950, 1100, 1200, 1400, 1500]

# %%
# 63
print(amount_rdd.filter(lambda x: x > 5000).count())
# Out:
# 24

# %%
# 64
print(amount_rdd.filter(lambda x: x > 20000).count())
# Out:
# 8

# %%
# 65
print(amount_rdd.filter(lambda x: x > 10000).sum())
# Out:
# 337000

# %%
customer_comments=["service was excellent","mobile banking is easy","transfer completed quickly",
                   "deposit process was smooth","excellent customer support",
                   "loan payment completed successfully","banking app is excellent",
                   "service is fast and reliable"]
comment_rdd=spark.sparkContext.parallelize(customer_comments)

# %%
# 66
print(comment_rdd.flatMap(lambda x: x.split()).collect())
# Out:
# ['service', 'was', 'excellent', 'mobile', 'banking', 'is', 'easy', 'transfer', 'completed', 'quickly', 'deposit', 'process', 'was', 'smooth', 'excellent', 'customer', 'support', 'loan', 'payment', 'completed', 'successfully', 'banking', 'app', 'is', 'excellent', 'service', 'is', 'fast', 'and', 'reliable']

# %%
# 67
print(comment_rdd.flatMap(lambda x: x.split()).count())
# Out:
# 30

# %%
# 68
print(comment_rdd.flatMap(lambda x: x.split()).distinct().collect())
# Out:
# ['service', 'banking', 'easy', 'transfer', 'deposit', 'support', 'payment', 'successfully', 'app', 'fast', 'and', 'reliable', 'was', 'excellent', 'mobile', 'is', 'completed', 'quickly', 'process', 'smooth', 'customer', 'loan']

# %%
# 69
print(comment_rdd.flatMap(lambda x: x.split()).distinct().sortBy(lambda x: x).collect())
# Out:
# ['and', 'app', 'banking', 'completed', 'customer', 'deposit', 'easy', 'excellent', 'fast', 'is', 'loan', 'mobile', 'payment', 'process', 'quickly', 'reliable', 'service', 'smooth', 'successfully', 'support', 'transfer', 'was']

# %%
# 70
print(comment_rdd.flatMap(lambda x: x.split()).map(lambda w: (w, 1)).reduceByKey(lambda a, b: a + b).collect())
# Out:
# [('service', 2), ('banking', 2), ('easy', 1), ('transfer', 1), ('deposit', 1), ('support', 1), ('payment', 1), ('successfully', 1), ('app', 1), ('fast', 1), ('and', 1), ('reliable', 1), ('was', 2), ('excellent', 3), ('mobile', 1), ('is', 3), ('completed', 2), ('quickly', 1), ('process', 1), ('smooth', 1), ('customer', 1), ('loan', 1)]

# %%
# 71
print(comment_rdd.flatMap(lambda x: x.split()).filter(lambda w: 'service' in w).collect())
# Out:
# ['service', 'service']

# %%
# 72
print(comment_rdd.flatMap(lambda x: x.split()).filter(lambda w: 'excellent' in w).collect())
# Out:
# ['excellent', 'excellent', 'excellent']

# %%
# 73
print(comment_rdd.flatMap(lambda x: x.split()).map(lambda w: w.upper()).collect())
# Out:
# ['SERVICE', 'WAS', 'EXCELLENT', 'MOBILE', 'BANKING', 'IS', 'EASY', 'TRANSFER', 'COMPLETED', 'QUICKLY', 'DEPOSIT', 'PROCESS', 'WAS', 'SMOOTH', 'EXCELLENT', 'CUSTOMER', 'SUPPORT', 'LOAN', 'PAYMENT', 'COMPLETED', 'SUCCESSFULLY', 'BANKING', 'APP', 'IS', 'EXCELLENT', 'SERVICE', 'IS', 'FAST', 'AND', 'RELIABLE']

# %%
# 74
print(comment_rdd.flatMap(lambda x: x.split()).sortBy(lambda w: len(w), ascending=False).first())
# Out:
# successfully

# %%
# 75
print(comment_rdd.flatMap(lambda x: x.split()).sortBy(lambda w: len(w)).first())
# Out:
# is

# %%
# 76
print(comment_rdd.flatMap(lambda x: x.split()).map(lambda w: (w, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).first())
# Out:
# ('excellent', 3)

# %%
# 77
print(comment_rdd.flatMap(lambda x: x.split()).map(lambda w: (w, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1]).first())
# Out:
# ('easy', 1)

# %%
# 78
print(comment_rdd.flatMap(lambda x: x.split()).filter(lambda w: w.startswith('b')).count())
# Out:
# 2

# %%
# 79
print(comment_rdd.flatMap(lambda x: x.split()).filter(lambda w: w.endswith('ly')).count())
# Out:
# 2

# %%
# 80
word_freq = comment_rdd.flatMap(lambda x: x.split()).map(lambda w: (w, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).collect()
for word, count in word_freq:
    print(f"{word}: {count}")
# Out:
# excellent: 3
# is: 3
# service: 2
# banking: 2
# was: 2
# completed: 2
# easy: 1
# transfer: 1
# deposit: 1
# support: 1
# payment: 1
# successfully: 1
# app: 1
# fast: 1
# and: 1
# reliable: 1
# mobile: 1
# quickly: 1
# process: 1
# smooth: 1
# customer: 1
# loan: 1

# %%
# 81
total = rdd.count()
deposit_count = rdd.filter(lambda x: x == 'DEPOSIT').count()
print(f"DEPOSIT: {round(deposit_count / total * 100, 2)}%")
# Out:
# DEPOSIT: 32.0%

# %%
# 82
total = rdd.count()
transfer_count = rdd.filter(lambda x: x == 'TRANSFER').count()
print(f"TRANSFER: {round(transfer_count / total * 100, 2)}%")
# Out:
# TRANSFER: 26.0%

# %%
# 83
total = rdd.count()
withdraw_count = rdd.filter(lambda x: x == 'WITHDRAW').count()
print(f"WITHDRAW: {round(withdraw_count / total * 100, 2)}%")
# Out:
# WITHDRAW: 20.0%

# %%
# 84
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).first())
# Out:
# ('DEPOSIT', 16)

# %%
# 85
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1]).first())
# Out:
# ('LOAN_PAYMENT', 5)

# %%
# 86
freq = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).collect()
print("=== Transaction Summary Report ===")
for txn, count in freq:
    print(f"{txn}: {count}")
# Out:
# === Transaction Summary Report ===
# DEPOSIT: 16
# TRANSFER: 13
# WITHDRAW: 10
# BALANCE_CHECK: 6
# LOAN_PAYMENT: 5

# %%
# 87
distinct = rdd.distinct().sortBy(lambda x: x).collect()
print("=== Unique Transaction Report ===")
for t in distinct:
    print(t)
# Out:
# === Unique Transaction Report ===
# BALANCE_CHECK
# DEPOSIT
# LOAN_PAYMENT
# TRANSFER
# WITHDRAW

# %%
# 88
freq = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).collect()
print("=== Frequency Report ===")
for txn, count in freq:
    print(f"{txn}: {count}")
# Out:
# === Frequency Report ===
# DEPOSIT: 16
# TRANSFER: 13
# WITHDRAW: 10
# BALANCE_CHECK: 6
# LOAN_PAYMENT: 5

# %%
# 89
rdd.distinct().sortBy(lambda x: x).saveAsTextFile("/tmp/unique_transactions")
print("Saved to /tmp/unique_transactions")
# Out:
# Saved to /tmp/unique_transactions

# %%
# 90
rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False) \
   .map(lambda x: f"{x[0]}: {x[1]}").saveAsTextFile("/tmp/transaction_frequencies")
print("Saved to /tmp/transaction_frequencies")
# Out:
# Saved to /tmp/transaction_frequencies

# %%
# 91
print(rdd.count())
# Out:
# 50

# %%
# 92
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).take(3))
# Out:
# [('DEPOSIT', 16), ('TRANSFER', 13), ('WITHDRAW', 10)]

# %%
# 93
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1]).take(3))
# Out:
# [('LOAN_PAYMENT', 5), ('BALANCE_CHECK', 6), ('WITHDRAW', 10)]

# %%
# 94
print(rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).collect())
# Out:
# [('DEPOSIT', 16), ('TRANSFER', 13), ('WITHDRAW', 10), ('BALANCE_CHECK', 6), ('LOAN_PAYMENT', 5)]

# %%
# 95
total = rdd.count()
freq = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).collect()
print("=== Final Banking Analytics Report ===")
print(f"Total Transactions: {total}")
print(f"Unique Types: {rdd.distinct().count()}")
print("Frequencies:")
for txn, count in freq:
    print(f"  {txn}: {count} ({round(count/total*100,2)}%)")
# Out:
# === Final Banking Analytics Report ===
# Total Transactions: 50
# Unique Types: 5
# Frequencies:
#   DEPOSIT: 16 (32.0%)
#   TRANSFER: 13 (26.0%)
#   WITHDRAW: 10 (20.0%)
#   BALANCE_CHECK: 6 (12.0%)
#   LOAN_PAYMENT: 5 (10.0%)

# %%
# 96
print(amount_rdd.sum())
# Out:
# 463750

# %%
# 97
print(amount_rdd.mean())
# Out:
# 9275.0

# %%
# 98
print(amount_rdd.filter(lambda x: x > 20000).collect())
# Out:
# [22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]

# %%
# 99
print(amount_rdd.filter(lambda x: x < 1000).collect())
# Out:
# [500, 800, 950, 750, 700, 900]

# %%
# 100
total_txns = rdd.count()
freq = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], ascending=False).collect()
total_amt = amount_rdd.sum()
avg_amt = amount_rdd.mean()
high_val = amount_rdd.filter(lambda x: x > 20000).count()
low_val = amount_rdd.filter(lambda x: x < 1000).count()

print("========================================")
print("     BANK TRANSACTION DASHBOARD")
print("========================================")
print(f"Total Transactions  : {total_txns}")
print(f"Unique Types        : {rdd.distinct().count()}")
print(f"Total Amount        : {total_amt}")
print(f"Average Amount      : {round(avg_amt, 2)}")
print(f"High-Value (>20000) : {high_val}")
print(f"Low-Value  (<1000)  : {low_val}")
print("--- Frequency Breakdown ---")
for txn, count in freq:
    print(f"  {txn}: {count}")
print("========================================")
# Out:
# ...
#      BANK TRANSACTION DASHBOARD
# ...
# Total Transactions  : 50
# Unique Types        : 5
# Total Amount        : 463750
# Average Amount      : 9275.0
# High-Value (>20000) : 8
# Low-Value  (<1000)  : 6
# --- Frequency Breakdown ---
#   DEPOSIT: 16
#   TRANSFER: 13
#   WITHDRAW: 10
#   BALANCE_CHECK: 6
#   LOAN_PAYMENT: 5
# ...
