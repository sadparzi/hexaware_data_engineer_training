# %% [markdown]
# # Solved PySpark DataFrame Exercises

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.appName("DataFrame Exercises").getOrCreate()

data = [
    (1, "Rahul Sharma", "Hyderabad", "Electronics", "Laptop", 1, 65000, "Delivered"),
    (2, "Priya Reddy", "Bangalore", "Electronics", "Mobile", 2, 25000, "Delivered"),
    (3, "Amit Kumar", "Mumbai", "Furniture", "Chair", 4, 3500, "Pending"),
    (4, "Sneha Patel", "Chennai", "Electronics", "Tablet", 1, 30000, "Cancelled"),
    (5, "Farhan Ali", "Delhi", "Furniture", "Table", 2, 12000, "Delivered"),
    (6, "Neha Singh", "Hyderabad", "Fashion", "Shoes", 3, 2500, "Delivered"),
    (7, "Arjun Verma", "Pune", "Fashion", "Watch", 1, 8000, "Pending"),
    (8, "Meera Nair", "Bangalore", "Electronics", "TV", 1, 45000, "Delivered"),
    (9, "Kiran Rao", "Hyderabad", "Furniture", "Desk", 1, 15000, "Delivered"),
    (10, "Ravi Kumar", "Mumbai", "Electronics", "Mobile", 1, 28000, "Delivered")
]

columns = ["order_id","customer_name","city","category","product","quantity","price","order_status"]
df = spark.createDataFrame(data, columns)

df = df.withColumn("total_amount", col("quantity") * col("price"))
df = df.withColumn("discount", col("total_amount") * 0.10)
df = df.withColumn("final_amount", col("total_amount") - col("discount"))

# %% [markdown]
# ## Exercise 1

# %%
df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 2

# %%
df.select("customer_name","city","product").show()
# Out:
# +-------------+---------+-------+
# |customer_name|     city|product|
# +-------------+---------+-------+
# | Rahul Sharma|Hyderabad| Laptop|
# |  Priya Reddy|Bangalore| Mobile|
# |   Amit Kumar|   Mumbai|  Chair|
# |  Sneha Patel|  Chennai| Tablet|
# |   Farhan Ali|    Delhi|  Table|
# |   Neha Singh|Hyderabad|  Shoes|
# |  Arjun Verma|     Pune|  Watch|
# |   Meera Nair|Bangalore|     TV|
# |    Kiran Rao|Hyderabad|   Desk|
# |   Ravi Kumar|   Mumbai| Mobile|
# +-------------+---------+-------+

# %% [markdown]
# ## Exercise 3

# %%
df.select("product","price").show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | Laptop|65000|
# | Mobile|25000|
# |  Chair| 3500|
# | Tablet|30000|
# |  Table|12000|
# |  Shoes| 2500|
# |  Watch| 8000|
# |     TV|45000|
# |   Desk|15000|
# | Mobile|28000|
# +-------+-----+

# %% [markdown]
# ## Exercise 4

# %%
df.filter(col("city")=="Hyderabad").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 5

# %%
df.filter(col("city")=="Bangalore").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 6

# %%
df.filter(col("category")=="Electronics").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 7

# %%
df.filter(col("category")=="Furniture").show()
# Out:
# +--------+-------------+---------+---------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city| category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+---------+-------+--------+-----+------------+------------+--------+------------+
# |       3|   Amit Kumar|   Mumbai|Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       5|   Farhan Ali|    Delhi|Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       9|    Kiran Rao|Hyderabad|Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# +--------+-------------+---------+---------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 8

# %%
df.filter(col("price")>30000).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 9

# %%
df.filter(col("quantity")>1).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 10

# %%
df.filter(col("order_status")=="Delivered").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 11

# %%
df.filter(col("order_status")=="Pending").show()
# Out:
# +--------+-------------+------+---------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|  city| category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+------+---------+-------+--------+-----+------------+------------+--------+------------+
# |       3|   Amit Kumar|Mumbai|Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       7|  Arjun Verma|  Pune|  Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# +--------+-------------+------+---------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 12

# %%
df.filter(col("order_status")=="Cancelled").show()
# Out:
# +--------+-------------+-------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|   city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+-------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       4|  Sneha Patel|Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# +--------+-------------+-------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 13

# %%
df.filter(col("city").isin("Hyderabad","Mumbai")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 14

# %%
df.filter(col("category").isin("Electronics","Fashion")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 15

# %%
df.filter(col("price").between(10000,50000)).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 16

# %%
df.orderBy("price").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 17

# %%
df.orderBy(col("price").desc()).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 18

# %%
df.orderBy("city","price").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 19

# %%
df.select("*","total_amount").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|total_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|       65000|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|       50000|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|       14000|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|       30000|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|       24000|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|        7500|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|        8000|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|       45000|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|       15000|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|       28000|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+------------+

# %% [markdown]
# ## Exercise 20

# %%
df.select("*","discount").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|discount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|  6500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|  5000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|  1400.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|  3000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|  2400.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|   750.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|   800.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|  4500.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|  1500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|  2800.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------+

# %% [markdown]
# ## Exercise 21

# %%
df.select("*","final_amount").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|     21600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|      6750.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|      7200.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|     40500.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|     13500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+------------+

# %% [markdown]
# ## Exercise 22

# %%
df.withColumnRenamed("customer_name","customer").show()
# Out:
# +--------+------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|    customer|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1|Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2| Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|  Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4| Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|  Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       6|  Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       7| Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# |       8|  Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       9|   Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |      10|  Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 23

# %%
df.withColumnRenamed("order_status","status").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|   status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|  Pending|       14000|  1400.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|Delivered|       24000|  2400.0|     21600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|Delivered|        7500|   750.0|      6750.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|  Pending|        8000|   800.0|      7200.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|Delivered|       45000|  4500.0|     40500.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|Delivered|       15000|  1500.0|     13500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+---------+------------+--------+------------+

# %% [markdown]
# ## Exercise 24

# %%
df.select(sum("total_amount")).show()
# Out:
# +-----------------+
# |sum(total_amount)|
# +-----------------+
# |           286500|
# +-----------------+

# %% [markdown]
# ## Exercise 25

# %%
df.select(avg("total_amount")).show()
# Out:
# +-----------------+
# |avg(total_amount)|
# +-----------------+
# |          28650.0|
# +-----------------+

# %% [markdown]
# ## Exercise 26

# %%
df.select(max("total_amount")).show()
# Out:
# +-----------------+
# |max(total_amount)|
# +-----------------+
# |            65000|
# +-----------------+

# %% [markdown]
# ## Exercise 27

# %%
df.select(min("total_amount")).show()
# Out:
# +-----------------+
# |min(total_amount)|
# +-----------------+
# |             7500|
# +-----------------+

# %% [markdown]
# ## Exercise 28

# %%
print(df.count())
# Out:
# 10

# %% [markdown]
# ## Exercise 29

# %%
df.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |  Chennai|    1|
# |   Mumbai|    2|
# |    Delhi|    1|
# |Hyderabad|    3|
# |     Pune|    1|
# +---------+-----+

# %% [markdown]
# ## Exercise 30

# %%
df.groupBy("category").count().show()
# Out:
# +-----------+-----+
# |   category|count|
# +-----------+-----+
# |Electronics|    5|
# |  Furniture|    3|
# |    Fashion|    2|
# +-----------+-----+

# %% [markdown]
# ## Exercise 31

# %%
df.groupBy("order_status").count().show()
# Out:
# +------------+-----+
# |order_status|count|
# +------------+-----+
# |   Cancelled|    1|
# |   Delivered|    7|
# |     Pending|    2|
# +------------+-----+

# %% [markdown]
# ## Exercise 32

# %%
df.groupBy("city").sum("total_amount").show()
# Out:
# +---------+-----------------+
# |     city|sum(total_amount)|
# +---------+-----------------+
# |Bangalore|            95000|
# |  Chennai|            30000|
# |   Mumbai|            42000|
# |    Delhi|            24000|
# |Hyderabad|            87500|
# |     Pune|             8000|
# +---------+-----------------+

# %% [markdown]
# ## Exercise 33

# %%
df.groupBy("category").sum("total_amount").show()
# Out:
# +-----------+-----------------+
# |   category|sum(total_amount)|
# +-----------+-----------------+
# |Electronics|           218000|
# |  Furniture|            53000|
# |    Fashion|            15500|
# +-----------+-----------------+

# %% [markdown]
# ## Exercise 34

# %%
df.groupBy("product").sum("total_amount").show()
# Out:
# +-------+-----------------+
# |product|sum(total_amount)|
# +-------+-----------------+
# |  Chair|            14000|
# | Laptop|            65000|
# |  Table|            24000|
# | Mobile|            78000|
# | Tablet|            30000|
# |     TV|            45000|
# |   Desk|            15000|
# |  Shoes|             7500|
# |  Watch|             8000|
# +-------+-----------------+

# %% [markdown]
# ## Exercise 35

# %%
df.groupBy("category").avg("price").show()
# Out:
# +-----------+------------------+
# |   category|        avg(price)|
# +-----------+------------------+
# |Electronics|           38600.0|
# |  Furniture|10166.666666666666|
# |    Fashion|            5250.0|
# +-----------+------------------+

# %% [markdown]
# ## Exercise 36

# %%
df.groupBy("category").max("price").show()
# Out:
# +-----------+----------+
# |   category|max(price)|
# +-----------+----------+
# |Electronics|     65000|
# |  Furniture|     15000|
# |    Fashion|      8000|
# +-----------+----------+

# %% [markdown]
# ## Exercise 37

# %%
df.groupBy("category").min("price").show()
# Out:
# +-----------+----------+
# |   category|min(price)|
# +-----------+----------+
# |Electronics|     25000|
# |  Furniture|      3500|
# |    Fashion|      2500|
# +-----------+----------+

# %% [markdown]
# ## Exercise 38

# %%
df.select("city").distinct().show()
# Out:
# +---------+
# |     city|
# +---------+
# |Bangalore|
# |  Chennai|
# |   Mumbai|
# |    Delhi|
# |Hyderabad|
# |     Pune|
# +---------+

# %% [markdown]
# ## Exercise 39

# %%
df.select("category").distinct().show()
# Out:
# +-----------+
# |   category|
# +-----------+
# |Electronics|
# |  Furniture|
# |    Fashion|
# +-----------+

# %% [markdown]
# ## Exercise 40

# %%
df.select("order_status").distinct().show()
# Out:
# +------------+
# |order_status|
# +------------+
# |   Cancelled|
# |   Delivered|
# |     Pending|
# +------------+

# %% [markdown]
# ## Exercise 41

# %%
df.orderBy(col("total_amount").desc()).show(3)
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# only showing top 3 rows

# %% [markdown]
# ## Exercise 42

# %%
df.orderBy("total_amount").show(1)
# Out:
# +--------+-------------+---------+--------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+--------+-------+--------+-----+------------+------------+--------+------------+
# |       6|   Neha Singh|Hyderabad| Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# +--------+-------------+---------+--------+-------+--------+-----+------------+------------+--------+------------+
# only showing top 1 row

# %% [markdown]
# ## Exercise 43

# %%
df.filter(col("product").startswith("M")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 44

# %%
df.filter(col("customer_name").contains("a")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 45

# %%
df.filter(col("product").contains("o")).show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+

# %% [markdown]
# ## Exercise 46

# %%
df = df.withColumn("order_value_category", when(col("total_amount")>=50000,"High").when(col("total_amount")>=20000,"Medium").otherwise("Low")); df.show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------------------+
# |order_id|customer_name|     city|   category|product|quantity|price|order_status|total_amount|discount|final_amount|order_value_category|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|   Delivered|       65000|  6500.0|     58500.0|                High|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|   Delivered|       50000|  5000.0|     45000.0|                High|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|     Pending|       14000|  1400.0|     12600.0|                 Low|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|   Cancelled|       30000|  3000.0|     27000.0|              Medium|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|   Delivered|       24000|  2400.0|     21600.0|              Medium|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|   Delivered|        7500|   750.0|      6750.0|                 Low|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|     Pending|        8000|   800.0|      7200.0|                 Low|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|   Delivered|       45000|  4500.0|     40500.0|              Medium|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|   Delivered|       15000|  1500.0|     13500.0|                 Low|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|   Delivered|       28000|  2800.0|     25200.0|              Medium|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+------------+--------+------------+--------------------+

# %% [markdown]
# ## Exercise 47

# %%
df.groupBy("order_value_category").count().show()
# Out:
# +--------------------+-----+
# |order_value_category|count|
# +--------------------+-----+
# |                High|    2|
# |                 Low|    4|
# |              Medium|    4|
# +--------------------+-----+

# %% [markdown]
# ## Exercise 48

# %%
df.filter(col("order_status")=="Delivered").select("customer_name","final_amount").show()
# Out:
# +-------------+------------+
# |customer_name|final_amount|
# +-------------+------------+
# | Rahul Sharma|     58500.0|
# |  Priya Reddy|     45000.0|
# |   Farhan Ali|     21600.0|
# |   Neha Singh|      6750.0|
# |   Meera Nair|     40500.0|
# |    Kiran Rao|     13500.0|
# |   Ravi Kumar|     25200.0|
# +-------------+------------+

# %% [markdown]
# ## Exercise 49

# %%
df.filter(col("order_status")=="Delivered").groupBy("city").sum("final_amount").show()
# Out:
# +---------+-----------------+
# |     city|sum(final_amount)|
# +---------+-----------------+
# |Bangalore|          85500.0|
# |    Delhi|          21600.0|
# |Hyderabad|          78750.0|
# |   Mumbai|          25200.0|
# +---------+-----------------+

# %% [markdown]
# ## Exercise 50

# %%
df.select("order_id","customer_name","city","category","product","quantity","price","total_amount","discount","final_amount","order_status").show()
# Out:
# +--------+-------------+---------+-----------+-------+--------+-----+------------+--------+------------+------------+
# |order_id|customer_name|     city|   category|product|quantity|price|total_amount|discount|final_amount|order_status|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+--------+------------+------------+
# |       1| Rahul Sharma|Hyderabad|Electronics| Laptop|       1|65000|       65000|  6500.0|     58500.0|   Delivered|
# |       2|  Priya Reddy|Bangalore|Electronics| Mobile|       2|25000|       50000|  5000.0|     45000.0|   Delivered|
# |       3|   Amit Kumar|   Mumbai|  Furniture|  Chair|       4| 3500|       14000|  1400.0|     12600.0|     Pending|
# |       4|  Sneha Patel|  Chennai|Electronics| Tablet|       1|30000|       30000|  3000.0|     27000.0|   Cancelled|
# |       5|   Farhan Ali|    Delhi|  Furniture|  Table|       2|12000|       24000|  2400.0|     21600.0|   Delivered|
# |       6|   Neha Singh|Hyderabad|    Fashion|  Shoes|       3| 2500|        7500|   750.0|      6750.0|   Delivered|
# |       7|  Arjun Verma|     Pune|    Fashion|  Watch|       1| 8000|        8000|   800.0|      7200.0|     Pending|
# |       8|   Meera Nair|Bangalore|Electronics|     TV|       1|45000|       45000|  4500.0|     40500.0|   Delivered|
# |       9|    Kiran Rao|Hyderabad|  Furniture|   Desk|       1|15000|       15000|  1500.0|     13500.0|   Delivered|
# |      10|   Ravi Kumar|   Mumbai|Electronics| Mobile|       1|28000|       28000|  2800.0|     25200.0|   Delivered|
# +--------+-------------+---------+-----------+-------+--------+-----+------------+--------+------------+------------+
